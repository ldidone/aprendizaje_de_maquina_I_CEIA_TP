# %% [markdown]
# # 1. Acoustic Extinguisher Fire Dataset

# %%
# Importamos las librerías necesarias
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import accuracy_score,plot_confusion_matrix,roc_auc_score, classification_report, confusion_matrix, precision_recall_curve, auc
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

import pickle
import joblib

# %%
# Levantamos el dataset
df = pd.read_excel('data/Acoustic_Extinguisher_Fire_Dataset.xlsx')

# %%
# Visualizamos los primeros 5 registros
df.head()
# Out:
#    SIZE      FUEL  DISTANCE  DESIBEL  AIRFLOW  FREQUENCY  STATUS
# 0     1  gasoline        10       96      0.0         75       0
# 1     1  gasoline        10       96      0.0         72       1
# 2     1  gasoline        10       96      2.6         70       1
# 3     1  gasoline        10       96      3.2         68       1
# 4     1  gasoline        10      109      4.5         67       1

# %% [markdown]
# ### Pre-procesamiento de los datos

# %% [markdown]
# #### 1. Renombrar columnas

# %%
columns = {
    'SIZE': 'size',
    'FUEL': 'fuel',
    'DISTANCE': 'distance',
    'DESIBEL': 'desibel',
    'AIRFLOW': 'airflow',
    'FREQUENCY': 'frequency',
    'STATUS': 'status',
}

df.rename(columns=columns, inplace=True)

# %% [markdown]
# #### 2. División de las variables predictoras (X) y variable objetivo (y)

# %%
# Definición de X e Y
X = df[['size', 'fuel', 'distance', 'desibel', 'airflow', 'frequency']]
y = df[['status']]

# %% [markdown]
# #### 3. Transformación de datos y pipeline de pre-procesamiento

# %%
numeric_features = ['size', 'distance', 'desibel', 'airflow', 'frequency']
categorical_features = ['fuel']

numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())])

categorical_transformer = OneHotEncoder(handle_unknown='ignore')

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])

# %% [markdown]
# #### 4. Separación en datos de entrenamiento y testeo

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, stratify=y)

# %%
print('Composición del training set:')
print(y_train.value_counts())

print('\nComposición del test set:')
print(y_test.value_counts())
# Out:
# Composición del training set:
# status
# 0         6131
# 1         6078
# dtype: int64
#
# Composición del test set:
# status
# 0         2628
# 1         2605
# dtype: int64

# %% [markdown]
# ### Preparación de la experimentación

# %% [markdown]
# #### 1. Definición del experimento

# %%
random_forest_pipe = Pipeline(steps=[('preprocessor', preprocessor),
                             ('classifier', RandomForestClassifier())])

# %%
param_grid = {
    'classifier__max_depth': [15, 30, 45],
    'classifier__n_estimators': [50, 100, 150],
    'classifier__criterion': ['gini', 'entropy', 'log_loss'],
}

# %%
search = GridSearchCV(random_forest_pipe, param_grid, cv=5, n_jobs=-1, verbose=3)

# %% [markdown]
# #### 2. Definición de las métricas

# %%
def metric_report(y_test, y_pred, y_proba):  
    print(classification_report(y_test, y_pred))  
    print('Area bajo la curva ROC:',np.round(roc_auc_score(y_test, y_proba[:,1]), 4)) 
    precision, recall,threshold=precision_recall_curve(y_test, y_proba[:,1]);
    print('Area bajo la curva Precision-Recall:',np.round(auc(recall, precision), 4))

# %% [markdown]
# ### Entrenamiento del modelo

# %%
search.fit(X_train, y_train.values.ravel())
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer(strategy='median')),
#                                                                                          ('scaler',
#                                                                                           StandardScaler())]),
#                                                                          ['size',
#                                                                           'distance',
#                                                                           'desibel',
#                                                                           'airflow',
#                                                                           'frequency']),
#                                                                         ('cat',
#                                                                          OneHotEncoder(handle_unknown='ignore'),
#                                                                          ['fuel'])])),
#                                        ('classifier',
#                                         RandomForestClassifier())]),
#              n_jobs=-1,
#              param_grid={'classifier__criterion': ['gini', 'entropy',
#                                                    'log_loss'],
#                          'classifier__max_depth': [15, 30, 45],
#                          'classifier__n_estimators': [50, 100, 150]},
#              verbose=3)

# %% [markdown]
# ### Análisis del resultado obtenido

# %%
pd.DataFrame(search.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        6.767012      0.109254         0.062502        0.009882
# 1       13.899997      0.142043         0.125003        0.009883
# 2       20.667855      0.407593         0.165626        0.015934
# 3        6.841090      0.172164         0.062501        0.009883
# 4       13.415856      0.375054         0.131249        0.007652
# 5       20.759638      0.268269         0.168750        0.018222
# 6        6.929847      0.259117         0.068751        0.007654
# 7       13.900000      0.361826         0.131248        0.015933
# 8       21.405835      0.276887         0.190625        0.011693
# 9        6.979001      0.258287         0.071876        0.012499
# 10      13.500811      0.437270         0.125001        0.017117
# 11      20.354394      0.128054         0.172325        0.010388
# 12       6.701045      0.126258         0.075000        0.018222
# 13      13.731810      0.178723         0.140626        0.013976
# 14      20.582434      0.667805         0.171877        0.022099
# 15       6.923186      0.142194         0.065627        0.011690
# 16      13.883944      0.161300         0.125001        0.017116
# 17      20.777671      0.373800         0.162502        0.035078
# 18       6.987499      0.472631         0.059378        0.022965
# 19      13.175098      0.319657         0.115625        0.007654
# 20      20.415207      0.521274         0.181250        0.021194
# 21       6.749232      0.094198         0.065626        0.006251
# 22      13.478586      0.196138         0.106250        0.011694
# 23      20.171564      0.261843         0.156254        0.013979
# 24       6.645056      0.224545         0.062500        0.013976
# 25      13.581250      0.138489         0.128125        0.015310
# 26      18.325303      2.162398         0.159378        0.043527
#
#    param_classifier__criterion param_classifier__max_depth  \
# 0                         gini                          15
# 1                         gini                          15
# 2                         gini                          15
# 3                         gini                          30
# 4                         gini                          30
# 5                         gini                          30
# 6                         gini                          45
# 7                         gini                          45
# 8                         gini                          45
# 9                      entropy                          15
# 10                     entropy                          15
# 11                     entropy                          15
# 12                     entropy                          30
# 13                     entropy                          30
# 14                     entropy                          30
# 15                     entropy                          45
# 16                     entropy                          45
# 17                     entropy                          45
# 18                    log_loss                          15
# 19                    log_loss                          15
# 20                    log_loss                          15
# 21                    log_loss                          30
# 22                    log_loss                          30
# 23                    log_loss                          30
# 24                    log_loss                          45
# 25                    log_loss                          45
# 26                    log_loss                          45
#
#    param_classifier__n_estimators  \
# 0                              50
# 1                             100
# 2                             150
# 3                              50
# 4                             100
# 5                             150
# 6                              50
# 7                             100
# 8                             150
# 9                              50
# 10                            100
# 11                            150
# 12                             50
# 13                            100
# 14                            150
# 15                             50
# 16                            100
# 17                            150
# 18                             50
# 19                            100
# 20                            150
# 21                             50
# 22                            100
# 23                            150
# 24                             50
# 25                            100
# 26                            150
#
#                                                params  split0_test_score  \
# 0   {'classifier__criterion': 'gini', 'classifier_...           0.962735
# 1   {'classifier__criterion': 'gini', 'classifier_...           0.961916
# 2   {'classifier__criterion': 'gini', 'classifier_...           0.965602
# 3   {'classifier__criterion': 'gini', 'classifier_...           0.961507
# 4   {'classifier__criterion': 'gini', 'classifier_...           0.964373
# 5   {'classifier__criterion': 'gini', 'classifier_...           0.964783
# 6   {'classifier__criterion': 'gini', 'classifier_...           0.962326
# 7   {'classifier__criterion': 'gini', 'classifier_...           0.965602
# 8   {'classifier__criterion': 'gini', 'classifier_...           0.963554
# 9   {'classifier__criterion': 'entropy', 'classifi...           0.962735
# 10  {'classifier__criterion': 'entropy', 'classifi...           0.966421
# 11  {'classifier__criterion': 'entropy', 'classifi...           0.965602
# 12  {'classifier__criterion': 'entropy', 'classifi...           0.965192
# 13  {'classifier__criterion': 'entropy', 'classifi...           0.963964
# 14  {'classifier__criterion': 'entropy', 'classifi...           0.965192
# 15  {'classifier__criterion': 'entropy', 'classifi...           0.965192
# 16  {'classifier__criterion': 'entropy', 'classifi...           0.965192
# 17  {'classifier__criterion': 'entropy', 'classifi...           0.966421
# 18  {'classifier__criterion': 'log_loss', 'classif...           0.964373
# 19  {'classifier__criterion': 'log_loss', 'classif...           0.965602
# 20  {'classifier__criterion': 'log_loss', 'classif...           0.961916
# 21  {'classifier__criterion': 'log_loss', 'classif...           0.966011
# 22  {'classifier__criterion': 'log_loss', 'classif...           0.963554
# 23  {'classifier__criterion': 'log_loss', 'classif...           0.963554
# 24  {'classifier__criterion': 'log_loss', 'classif...           0.963964
# 25  {'classifier__criterion': 'log_loss', 'classif...           0.964783
# 26  {'classifier__criterion': 'log_loss', 'classif...           0.965602
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.958231           0.975430           0.966421
# 1            0.962326           0.974611           0.966830
# 2            0.962735           0.973382           0.965602
# 3            0.961916           0.972973           0.964373
# 4            0.962735           0.972154           0.964783
# 5            0.959459           0.971744           0.966011
# 6            0.961507           0.975020           0.964783
# 7            0.962326           0.970925           0.965192
# 8            0.963145           0.972563           0.965602
# 9            0.962326           0.973792           0.966830
# 10           0.965192           0.975430           0.968059
# 11           0.963964           0.975020           0.968878
# 12           0.966011           0.972563           0.967649
# 13           0.963964           0.975839           0.967649
# 14           0.964373           0.974201           0.968878
# 15           0.963145           0.973382           0.967240
# 16           0.963964           0.975430           0.968468
# 17           0.963145           0.975839           0.969287
# 18           0.963554           0.972563           0.968878
# 19           0.963554           0.974611           0.966830
# 20           0.963145           0.975430           0.968059
# 21           0.961097           0.974611           0.966011
# 22           0.963964           0.972973           0.966421
# 23           0.966830           0.975020           0.967240
# 24           0.961916           0.971335           0.968468
# 25           0.965192           0.977068           0.968878
# 26           0.965192           0.975020           0.968468
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.965998         0.965763        0.005654               25
# 1            0.965588         0.966254        0.004579               23
# 2            0.966407         0.966746        0.003546               20
# 3            0.966407         0.965435        0.004164               27
# 4            0.967636         0.966336        0.003310               22
# 5            0.966407         0.965681        0.003922               26
# 6            0.970094         0.966746        0.005109               19
# 7            0.966407         0.966091        0.002782               24
# 8            0.967636         0.966500        0.003429               21
# 9            0.970914         0.967319        0.004494               15
# 10           0.968865         0.968794        0.003555                3
# 11           0.966817         0.968056        0.003834               10
# 12           0.968046         0.967893        0.002558               11
# 13           0.968865         0.968056        0.004356                9
# 14           0.971323         0.968794        0.003692                2
# 15           0.970094         0.967811        0.003611               12
# 16           0.970094         0.968630        0.004050                4
# 17           0.965998         0.968138        0.004315                8
# 18           0.968046         0.967483        0.003261               14
# 19           0.970504         0.968220        0.003914                7
# 20           0.970094         0.967729        0.004895               13
# 21           0.968046         0.967155        0.004375               17
# 22           0.968865         0.967156        0.003477               16
# 23           0.970094         0.968548        0.003844                6
# 24           0.968456         0.966828        0.003405               18
# 25           0.969685         0.969121        0.004422                1
# 26           0.968865         0.968630        0.003519                5

# %%
search.best_estimator_
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['size', 'distance',
#                                                    'desibel', 'airflow',
#                                                    'frequency']),
#                                                  ('cat',
#                                                   OneHotEncoder(handle_unknown='ignore'),
#                                                   ['fuel'])])),
#                 ('classifier',
#                  RandomForestClassifier(criterion='log_loss', max_depth=45))])

# %%
search.best_score_
# Out:
# 0.9691211862862825

# %%
y_pred = search.predict(X_test)

# %%
y_proba = search.predict_proba(X_test)

# %%
metric_report(y_test, y_pred, y_proba)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.98      0.97      2628
#            1       0.98      0.96      0.97      2605
#
#     accuracy                           0.97      5233
#    macro avg       0.97      0.97      0.97      5233
# weighted avg       0.97      0.97      0.97      5233
#
# Area bajo la curva ROC: 0.9963
# Area bajo la curva Precision-Recall: 0.9964

# %%
# save the model
filename = 'models/random_forest_search.sav'
pickle.dump(search, open(filename, 'wb'))

# %% [markdown]
# ### Conclusión:
#
# Hemos realizado una búsqueda hiperparamétrica sobre el modelo de random forest, con el objetivo de encontrar un modelo que performe de manera superior al de árboles de decisión entrenado previamente. Y hemos hayado que con los parámetros: **max_depth=45, criterion='log_loss' y n_estimators=100**, se obtiene el mejor estimador.
#
# No obstante, la mejora obtenida es del 1% sobre la métrica f1-score, pero el modelo almacenado ocupa 10 veces más espacio. Por lo que concluimos que si bien el modelo performa mejor, no creemos que valga la pena utilizarlo en lugar del árbol de decisión ya que añade mucha complejidad, perdiendo interpretabilidad, por una performance levemente superior.
